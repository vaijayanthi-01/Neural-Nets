# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
from random import random

def generate_dataset(num_samples, test_size=0.33):
  x = np.array([[random() / 2 for _ in range(2)] for _ in range(num_samples)])
  y = np.array([[i[0] + i[1]] for i in x])

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = test_size)
  return x_train, x_test, y_train, y_test

if __name__ == "__main__":
  x_train, x_test, y_train, y_test = generate_dataset(10000, 0.3)

  # build model
  model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(5, input_dim=2, activation="sigmoid"),
    tf.keras.layers.Dense(1, activation="sigmoid")
  ])

  # compile model
  optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
  model.compile(optimizer=optimizer, loss="mse")

  # train model
  model.fit(x_train, y_train, epochs=100)
  print()
  print()

  # evaluate model
  model.evaluate(x_test, y_test, verbose=1)

  # make predictions
  data = np.array([[0.1, 0.2], [0.2, 0.2]])
  prediction = model.predict(data)

  print()
  print()
  print("Predictions:")
  for d, p in zip(data, prediction):
    print("{} + {} = {}".format(d[0], d[1], p[0]))
# Out:
# Epoch 1/100
# 219/219 [==============================] - 1s 1ms/step - loss: 0.0440
# Epoch 2/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0410
# Epoch 3/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0405
# Epoch 4/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0401
# Epoch 5/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0395
# Epoch 6/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0390
# Epoch 7/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0384
# Epoch 8/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0378
# Epoch 9/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0372
# Epoch 10/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0364
# Epoch 11/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0356
# Epoch 12/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0348
# Epoch 13/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 14/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 15/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0317
# Epoch 16/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0306
# Epoch 17/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0293
# Epoch 18/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0280
# Epoch 19/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 20/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 21/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 22/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0220
# Epoch 23/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0205
# Epoch 24/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0189
# Epoch 25/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0173
# Epoch 26/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0158
# Epoch 27/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0144
# Epoch 28/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 29/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0117
# Epoch 30/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0105
# Epoch 31/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 32/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0084
# Epoch 33/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0075
# Epoch 34/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0066
# Epoch 35/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0059
# Epoch 36/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0052
# Epoch 37/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0046
# Epoch 38/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 39/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 40/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 41/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 42/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 43/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 44/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 45/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 46/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 47/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 48/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 49/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 50/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 51/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 52/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 53/100
# 219/219 [==============================] - 0s 1ms/step - loss: 9.4249e-04
# Epoch 54/100
# 219/219 [==============================] - 0s 1ms/step - loss: 8.8417e-04
# Epoch 55/100
# 219/219 [==============================] - 0s 1ms/step - loss: 8.3338e-04
# Epoch 56/100
# 219/219 [==============================] - 0s 1ms/step - loss: 7.8931e-04
# Epoch 57/100
# 219/219 [==============================] - 0s 1ms/step - loss: 7.5090e-04
# Epoch 58/100
# 219/219 [==============================] - 0s 1ms/step - loss: 7.1744e-04
# Epoch 59/100
# 219/219 [==============================] - 0s 1ms/step - loss: 6.8847e-04
# Epoch 60/100
# 219/219 [==============================] - 0s 1ms/step - loss: 6.6317e-04
# Epoch 61/100
# 219/219 [==============================] - 0s 1ms/step - loss: 6.4136e-04
# Epoch 62/100
# 219/219 [==============================] - 0s 1ms/step - loss: 6.2216e-04
# Epoch 63/100
# 219/219 [==============================] - 0s 1ms/step - loss: 6.0563e-04
# Epoch 64/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.9111e-04
# Epoch 65/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.7852e-04
# Epoch 66/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.6758e-04
# Epoch 67/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.5797e-04
# Epoch 68/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.4966e-04
# Epoch 69/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.4235e-04
# Epoch 70/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.3586e-04
# Epoch 71/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.3046e-04
# Epoch 72/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.2557e-04
# Epoch 73/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.2133e-04
# Epoch 74/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.1754e-04
# Epoch 75/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.1431e-04
# Epoch 76/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.1139e-04
# Epoch 77/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.0899e-04
# Epoch 78/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.0677e-04
# Epoch 79/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.0486e-04
# Epoch 80/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.0307e-04
# Epoch 81/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.0157e-04
# Epoch 82/100
# 219/219 [==============================] - 0s 1ms/step - loss: 5.0024e-04
# Epoch 83/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9896e-04
# Epoch 84/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9792e-04
# Epoch 85/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9705e-04
# Epoch 86/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9620e-04
# Epoch 87/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9543e-04
# Epoch 88/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9472e-04
# Epoch 89/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9411e-04
# Epoch 90/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9355e-04
# Epoch 91/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9299e-04
# Epoch 92/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9264e-04
# Epoch 93/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9221e-04
# Epoch 94/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9175e-04
# Epoch 95/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9146e-04
# Epoch 96/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9113e-04
# Epoch 97/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9083e-04
# Epoch 98/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9036e-04
# Epoch 99/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.9011e-04
# Epoch 100/100
# 219/219 [==============================] - 0s 1ms/step - loss: 4.8992e-04
#
#
# 94/94 [==============================] - 0s 1ms/step - loss: 5.2630e-04
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7f6901eb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#
# Predictions:
# 0.1 + 0.2 = 0.2841622829437256
# 0.2 + 0.2 = 0.384469211101532
